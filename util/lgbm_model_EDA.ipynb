# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
result_df = pd.read_csv('CSV/lgbm_result.csv')
result_df
# Out:
#       test_who  song_id  test_order  f1_score              feat         mode
# 0            1        1           1    0.9417  acc + gyr + near   one-to-one
# 1            1        1           2    0.9553  acc + gyr + near   one-to-one
# 2            1        1           3    0.9446  acc + gyr + near   one-to-one
# 3            1        1           1    0.9388  acc + gyr + near  rest-to-one
# 4            1        1           2    0.9444  acc + gyr + near  rest-to-one
# 5            1        1           3    0.9413  acc + gyr + near  rest-to-one
# 6            1        1           1    0.9388  acc + gyr + near   all-to-one
# 7            1        1           2    0.9528  acc + gyr + near   all-to-one
# 8            1        1           3    0.9471  acc + gyr + near   all-to-one
# 9            2        1           1    0.9697  acc + gyr + near   one-to-one
# 10           2        1           2    0.8757  acc + gyr + near   one-to-one
# 11           2        1           3    0.9123  acc + gyr + near   one-to-one
# 12           2        1           1    0.9554  acc + gyr + near  rest-to-one
# 13           2        1           2    0.9228  acc + gyr + near  rest-to-one
# 14           2        1           3    0.9384  acc + gyr + near  rest-to-one
# 15           2        1           1    0.9806  acc + gyr + near   all-to-one
# 16           2        1           2    0.9341  acc + gyr + near   all-to-one
# 17           2        1           3    0.9722  acc + gyr + near   all-to-one
# 18           3        1           1    0.9441  acc + gyr + near   one-to-one
# 19           3        1           2    0.9753  acc + gyr + near   one-to-one
# 20           3        1           3    0.9889  acc + gyr + near   one-to-one
# 21           3        1           1    0.9862  acc + gyr + near  rest-to-one
# 22           3        1           2    0.9834  acc + gyr + near  rest-to-one
# 23           3        1           3    0.9862  acc + gyr + near  rest-to-one
# 24           3        1           1    0.9834  acc + gyr + near   all-to-one
# 25           3        1           2    0.9862  acc + gyr + near   all-to-one
# 26           3        1           3    0.9835  acc + gyr + near   all-to-one
# 27           4        1           1    0.9322  acc + gyr + near   one-to-one
# 28           4        1           2    0.9368  acc + gyr + near   one-to-one
# 29           4        1           3    0.9725  acc + gyr + near   one-to-one
# ...        ...      ...         ...       ...               ...          ...
# 1806         6        4           3    0.6134               gyr  rest-to-one
# 1807         6        4           4    0.6018               gyr  rest-to-one
# 1808         6        4           1    0.6241               gyr   all-to-one
# 1809         6        4           2    0.6027               gyr   all-to-one
# 1810         6        4           3    0.6265               gyr   all-to-one
# 1811         6        4           4    0.6204               gyr   all-to-one
# 1812         7        4           1    0.7709               gyr   one-to-one
# 1813         7        4           2    0.7448               gyr   one-to-one
# 1814         7        4           3    0.6906               gyr   one-to-one
# 1815         7        4           4    0.5566               gyr   one-to-one
# 1816         7        4           1    0.6698               gyr  rest-to-one
# 1817         7        4           2    0.6290               gyr  rest-to-one
# 1818         7        4           3    0.6531               gyr  rest-to-one
# 1819         7        4           4    0.6292               gyr  rest-to-one
# 1820         7        4           1    0.7519               gyr   all-to-one
# 1821         7        4           2    0.7192               gyr   all-to-one
# 1822         7        4           3    0.7237               gyr   all-to-one
# 1823         7        4           4    0.5687               gyr   all-to-one
# 1824         8        4           1    0.6077               gyr   one-to-one
# 1825         8        4           2    0.5819               gyr   one-to-one
# 1826         8        4           3    0.5642               gyr   one-to-one
# 1827         8        4           4    0.5950               gyr   one-to-one
# 1828         8        4           1    0.6350               gyr  rest-to-one
# 1829         8        4           2    0.6086               gyr  rest-to-one
# 1830         8        4           3    0.6289               gyr  rest-to-one
# 1831         8        4           4    0.6162               gyr  rest-to-one
# 1832         8        4           1    0.6565               gyr   all-to-one
# 1833         8        4           2    0.6159               gyr   all-to-one
# 1834         8        4           3    0.6215               gyr   all-to-one
# 1835         8        4           4    0.6156               gyr   all-to-one
#
# [1836 rows x 6 columns]

# %%
sns.catplot(x="test_who", y="f1_score",
            capsize=.3, aspect=2,
            
            kind="point", data=result_df, hue='song_id', col='mode', row='feat', vmax=1)
plt.show()

# %%
sns.catplot(x="test_who", y="f1_score", capsize=.3, aspect=2,
            kind="point", data=result_df, hue='feat', row='song_id', col='mode', vmax=1)
plt.show()

sns.catplot(x="test_who", y="f1_score", aspect=2,
            kind="box", data=result_df, hue='feat', row='song_id', col='mode')
plt.show()

# %%
plt.figure(figsize=(12, 20))
sns.boxplot(y='test_who', x='f1_score', data=result_df, hue='feat', orient='h')
plt.show()
