# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
result_df = pd.read_csv('CSV/lgbm_result_big_small.csv')
result_df
# Out:
#       test_who  song_id  test_order  f1_score              feat         mode
# 0            1        1           1    0.9206  acc + gyr + near   one-to-one
# 1            1        1           2    0.9461  acc + gyr + near   one-to-one
# 2            1        1           3    0.9308  acc + gyr + near   one-to-one
# 3            1        1           1    0.9360  acc + gyr + near  rest-to-one
# 4            1        1           2    0.9439  acc + gyr + near  rest-to-one
# 5            1        1           3    0.9436  acc + gyr + near  rest-to-one
# 6            1        1           1    0.9511  acc + gyr + near   all-to-one
# 7            1        1           2    0.9590  acc + gyr + near   all-to-one
# 8            1        1           3    0.9590  acc + gyr + near   all-to-one
# 9            2        1           1    0.9671  acc + gyr + near   one-to-one
# 10           2        1           2    0.8728  acc + gyr + near   one-to-one
# ...

# %%
sns.catplot(x="test_who", y="f1_score",
            capsize=.3, aspect=2,
            
            kind="point", data=result_df, hue='song_id', col='mode', row='feat', vmax=1)
plt.show()

# %%
sns.catplot(x="test_who", y="f1_score", capsize=.3, aspect=2,
            kind="point", data=result_df, hue='feat', row='song_id', col='mode', vmax=1)
plt.show()

sns.catplot(x="test_who", y="f1_score", aspect=2,
            kind="box", data=result_df, hue='feat', row='song_id', col='mode')
plt.show()

# %%
plt.figure(figsize=(12, 20))
sns.boxplot(y='test_who', x='f1_score', data=result_df, hue='feat', orient='h')
plt.show()
