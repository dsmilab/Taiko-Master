# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Load" data-toc-modified-id="Load-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#LGBM-training" data-toc-modified-id="LGBM-training-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>LGBM training</a></span><ul class="toc-item"><li><span><a href="#Prepare" data-toc-modified-id="Prepare-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Prepare</a></span></li><li><span><a href="#Core" data-toc-modified-id="Core-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Core</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Load

# %%
import taiko as tk
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import tqdm
import lightgbm as lgb
from sklearn import metrics

SONG = 1
WHO = 7
TRAIN_ORDER = 3
# Out:
# Using TensorFlow backend.

# %%
pfs = []
for drummer in tqdm(range(1, 8 + 1)):
    ppf = []
    for order_id in range(1, 3 + 1):
        ppf.append(tk.get_event_primitive_df(drummer, SONG, order_id, False, False))
    pfs.append(ppf)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 46.33it/s]

# %%
def soso(who_id, song_id):
    sfs = []
    for pf_order in range(1, 3 + 1):
        score = tk.get_score(who_id, song_id, pf_order)
        sfs.append(score)
    return sfs

# %%
sfs = []
for drummer in range(1, 8 + 1):
    sfs.append(soso(drummer, SONG))

# %%
sfs[0][0]
# Out:
# 243400

# %%
pfs[0][2]
# Out:
#      hit_type     R_AAI     R_AVI    R_ASMA       R_GAI        R_GVI  \
# 0           1  0.536254  0.197231  0.779857   47.798923   622.781802
# 1           0  0.122777  0.003575  0.169714   51.768430   114.382394
# 2           0  0.116889  0.000301  0.193500   22.870672    52.369331
# 3           0  0.148152  0.000085  0.161667   11.771275     1.311274
# 4           1  0.147064  0.000552  0.189000   17.024842    22.130267
# 5           0  0.100508  0.000692  0.149714    8.155723    29.977972
# 6           0  0.114612  0.000384  0.149125   20.859165    42.739004
# 7           0  0.060362  0.000424  0.098167   31.362174    22.449304
# 8           1  0.262484  0.026167  0.376000   58.165062   621.050045
# 9           0  0.105672  0.002816  0.166429   27.458307    27.648758
# 10          1  0.073104  0.000154  0.113429   14.507212    11.025561
# 11          0  0.081100  0.000216  0.119200   11.999277    35.168313
# 12          1  0.336400  0.021584  0.486571   71.823238  1546.168375
# 13          0  0.118307  0.003618  0.181143   35.070070    34.954341
# 14          0  0.063027  0.000205  0.094714   18.042411    92.203900
# 15          0  0.031172  0.000110  0.051000   19.502855     9.262453
# 16          1  0.270902  0.027718  0.382143   65.402262   716.653490
# 17          0  0.070069  0.000094  0.109500   32.057733    40.970206
# 18          0  0.064681  0.000531  0.083000   11.603328    11.457431
# 19          0  0.112090  0.000251  0.162400    7.378536     2.627429
# 20          1  0.112086  0.000386  0.156333    9.285054     3.692070
# 21          0  0.115294  0.000029  0.159857    7.777024     8.993880
# 22          0  0.086002  0.000163  0.123857   27.268426    17.081594
# 23          0  0.091626  0.002619  0.140714   28.278563    80.337821
# 24          2  0.277608  0.012616  0.420857   59.398483   400.583219
# 25          2  0.736805  0.053874  1.110875  128.401117  3093.232915
# 26          2  0.749257  0.022004  1.175250  121.721087  2453.563461
# 27          2  0.764239  0.052291  1.073600  112.688265   623.710245
# 28          2  0.593863  0.023253  0.916667  114.610188  1424.308550
# 29          2  0.574937  0.061536  0.914571  100.673765  2407.268776
# 334  -0.883284   0.246583   0.600476   0.621093   0   1   0   1
# 335  -0.583652   0.688298  -0.466327  -0.341797   0   0   1   0
# 336   0.886511  -0.792142  -0.597149   0.824289   0   0   0   0
# 337   0.669957  -0.904988  -0.843676   0.988373   1   0   0   0
# 338  -0.758599  -0.380028  -0.720243   0.188355   0   1   0   1
# 339  -0.518058  -0.552587  -0.543356   0.496105   0   0   1   0
# 340  -0.205999   0.908811  -0.409049  -0.623873   0   0   0   0
# 341   0.949642  -0.199119   0.279085  -0.788049   1   0   0   0
# 342  -0.850737   0.607305  -0.099750  -0.342637   0   1   0   1
# 343  -0.924865   0.787805  -0.522869  -0.430897   0   0   1   0
# 344  -0.156258  -0.033890   0.517452   0.594097   0   0   0   1
# 345  -0.826862   0.614927   0.074767   0.607718   1   0   1   0
# 346   0.754074   0.044597  -0.107143  -0.638551   0   1   0   1
# 347  -0.927285   0.122138  -0.674918  -0.627075   1   0   1   0
# 348   0.865858   0.120961   0.357374  -0.422413   0   1   0   1
# 349  -0.844949   0.494438  -0.816350   0.095357   1   0   1   0
# 350        NaN  -1.000000   1.000000  -1.000000   0   1   0   2
# 351  -0.799083   0.370215   0.128745   0.049267   1   0   2   2
# 352  -0.154857   0.278543   0.406928   0.037434   0   1   2   2
# 353  -0.748730  -0.434143   0.445785  -0.039776   2   0   2   2
# 354  -0.253457  -0.748403   0.273649  -0.034298   2   2   2   2
# 355  -0.450624   0.894150  -0.142683  -0.270445   2   2   2   2
# 356  -0.178708   0.094613   0.725434   0.217552   2   2   2   2
# 357  -0.242453   0.385616   0.849358  -0.116987   2   2   2   2
# 358   0.125888   0.609528   0.948743   0.625755   2   2   2   2
# 359   0.044993  -0.257288  -0.118921   0.965761   2   2   2   0
# 360   0.341576  -0.734168  -0.802536   0.943719   2   2   0   0
#
# [361 rows x 53 columns]

# %% [markdown]
# # LGBM training

# %% [markdown]
# ## Prepare

# %%
def prepare(train_who, train_porder, valid_who, valid_porder):
    train_df = pfs[train_who - 1][train_porder - 1]
    x = train_df.drop(['hit_type'], axis=1)
    y = train_df['hit_type']
    
    valid_df = pfs[valid_who - 1][valid_porder - 1]
    x_valid = valid_df.drop(['hit_type'], axis=1)
    y_valid = valid_df['hit_type']
    
    return x, y, x_valid, y_valid

# %%
params = dict({
    'learning_rate': 0.5,
    'application': 'multiclass',
    'num_classes': 3,
#     'min_data_in_leaf': 5,
#     'max_depth': 8,
    'num_leaves': 2 ** 4,
    'verbosity': 0,
#     'metric': 'multi_error'
})

grid_params = {
    'learning_rate': [0.1, 0.2],
    'max_depth': [8, 10],
}

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    return cm

# %%
def get_multi_error(y, pred_y):
    cnf_matrix = confusion_matrix(y, pred_y)
    
    # Plot normalized confusion matrix
#     plt.figure(figsize=(10, 10))
    cm = plot_confusion_matrix(cnf_matrix, classes=[0, 1, 2], normalize=True,
                          title='Normalized confusion matrix')
    return sum([1 - cm[i][i] for i in range(cm.shape[0])]) / cm.shape[0]

# %%
def my_f1_score(y_pred, y):

    y = y.get_label()
    y_pred = y_pred.reshape(len(np.unique(y)), -1).argmax(axis=0)
    return "f1-score", metrics.f1_score(y, y_pred, average="weighted"), True

# %% [markdown]
# ## Core

# %%
result_df = pd.DataFrame(columns=['train_who', 'train_porder', 'train_score', 'valid_who', 'valid_porder', 'valid_score', 'test_who', 'test_porder', 'test_score', 'f1_score'])
id_ = 0

for train_who in range(1, 8 + 1):
    for train_porder in range(1, 3 + 1):
        for valid_who in range(1, 8 + 1):
            for valid_porder in range(1, 3 + 1):
                x, y, x_valid, y_valid = prepare(train_who, train_porder, valid_who, valid_porder)
            
                train_set = lgb.Dataset(x, y)
                valid_set = lgb.Dataset(x_valid, y_valid, free_raw_data=False)

                watchlist = [valid_set]

                model = lgb.train(params, train_set=train_set, valid_sets=watchlist, num_boost_round=200, verbose_eval=50, early_stopping_rounds=100, feval=my_f1_score)

                for test_who in range(1, 8 + 1):
                    for test_porder in range(1, 3 + 1):

                        x_test = pfs[test_who - 1][test_porder - 1].drop(['hit_type'], axis=1)
                        y_true = pfs[test_who - 1][test_porder - 1]['hit_type']

                        y_pred = model.predict(x_test, num_iteration=model.best_iteration)
                        predictions = []
                        for xx in y_pred:
                            predictions.append(np.argmax(xx))
                        y_test = pd.Series(data=predictions)
                        
                        
                        f1_score = '%.4f' % metrics.f1_score(y_test, y_true, average = 'weighted')

    #                     train_str = '%d,%d' % (train_who, train_porder)
                        train_score = sfs[train_who - 1][train_porder - 1]

    #                     valid_str = '%d,%d' % (train_who, valid_porder)
                        valid_score = sfs[valid_who - 1][valid_porder - 1]

    #                     test_str = '%d,%d' % (test_who, test_porder)
                        test_score = sfs[test_who - 1][test_porder - 1]

                        result_df.loc[id_] = [train_who, train_porder, train_score, valid_who, valid_porder, valid_score, test_who, test_porder, test_score, f1_score]

                        id_ += 1
# Out:
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.950429
# [100]	valid_0's f1-score: 0.942391
# Early stopping, best iteration is:
# [17]	valid_0's f1-score: 0.950601
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.931553
# [100]	valid_0's f1-score: 0.931568
# Early stopping, best iteration is:
# [16]	valid_0's f1-score: 0.942796
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.808459
# [100]	valid_0's f1-score: 0.818946
# [150]	valid_0's f1-score: 0.816334
# Early stopping, best iteration is:
# [98]	valid_0's f1-score: 0.818946
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.811261
# [100]	valid_0's f1-score: 0.805399
# Early stopping, best iteration is:
# [46]	valid_0's f1-score: 0.822006
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.741998
# [100]	valid_0's f1-score: 0.736202
# Early stopping, best iteration is:
# [31]	valid_0's f1-score: 0.755607
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.897298
# [100]	valid_0's f1-score: 0.895028
# Early stopping, best iteration is:
# [40]	valid_0's f1-score: 0.909231
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.941643
# [100]	valid_0's f1-score: 0.933271
# Early stopping, best iteration is:
# [42]	valid_0's f1-score: 0.944529
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.930619
# [100]	valid_0's f1-score: 0.930791
# [150]	valid_0's f1-score: 0.933799
# [200]	valid_0's f1-score: 0.925755
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.724617
# [100]	valid_0's f1-score: 0.717607
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.750517
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.767035
# [100]	valid_0's f1-score: 0.781042
# Early stopping, best iteration is:
# [4]	valid_0's f1-score: 0.792625
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.76001
# [100]	valid_0's f1-score: 0.772922
# [150]	valid_0's f1-score: 0.776692
# Early stopping, best iteration is:
# [68]	valid_0's f1-score: 0.777832
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.829758
# [100]	valid_0's f1-score: 0.819588
# Early stopping, best iteration is:
# [13]	valid_0's f1-score: 0.842
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.746983
# [100]	valid_0's f1-score: 0.742264
# Early stopping, best iteration is:
# [2]	valid_0's f1-score: 0.897193
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.860546
# [100]	valid_0's f1-score: 0.852219
# Early stopping, best iteration is:
# [45]	valid_0's f1-score: 0.863961
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.794002
# [100]	valid_0's f1-score: 0.78519
# Early stopping, best iteration is:
# [7]	valid_0's f1-score: 0.814931
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.836838
# [100]	valid_0's f1-score: 0.821738
# Early stopping, best iteration is:
# [35]	valid_0's f1-score: 0.871866
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.860969
# [100]	valid_0's f1-score: 0.855102
# Early stopping, best iteration is:
# [42]	valid_0's f1-score: 0.880207
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.85033
# [100]	valid_0's f1-score: 0.864271
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 0.896886
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.894348
# [100]	valid_0's f1-score: 0.891714
# Early stopping, best iteration is:
# [40]	valid_0's f1-score: 0.905757
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.888073
# [100]	valid_0's f1-score: 0.876888
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.918047
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.847788
# [100]	valid_0's f1-score: 0.847788
# Early stopping, best iteration is:
# [16]	valid_0's f1-score: 0.862009
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.817097
# [100]	valid_0's f1-score: 0.808574
# [150]	valid_0's f1-score: 0.803541
# Early stopping, best iteration is:
# [56]	valid_0's f1-score: 0.827521
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.817976
# [100]	valid_0's f1-score: 0.815178
# Early stopping, best iteration is:
# [24]	valid_0's f1-score: 0.833942
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.930488
# [100]	valid_0's f1-score: 0.933186
# Early stopping, best iteration is:
# [33]	valid_0's f1-score: 0.944598
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.933541
# [100]	valid_0's f1-score: 0.930852
# Early stopping, best iteration is:
# [22]	valid_0's f1-score: 0.947478
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.826907
# [100]	valid_0's f1-score: 0.826787
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 0.866974
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.794869
# [100]	valid_0's f1-score: 0.784465
# Early stopping, best iteration is:
# [25]	valid_0's f1-score: 0.820967
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.763913
# [100]	valid_0's f1-score: 0.76614
# Early stopping, best iteration is:
# [25]	valid_0's f1-score: 0.777073
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.916221
# [100]	valid_0's f1-score: 0.902196
# Early stopping, best iteration is:
# [44]	valid_0's f1-score: 0.924183
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.930666
# [100]	valid_0's f1-score: 0.922251
# Early stopping, best iteration is:
# [23]	valid_0's f1-score: 0.938636
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.917672
# [100]	valid_0's f1-score: 0.917672
# [150]	valid_0's f1-score: 0.917672
# Early stopping, best iteration is:
# [59]	valid_0's f1-score: 0.923096
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.7248
# [100]	valid_0's f1-score: 0.72021
# Early stopping, best iteration is:
# [38]	valid_0's f1-score: 0.746219
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.780678
# [100]	valid_0's f1-score: 0.784655
# Early stopping, best iteration is:
# [32]	valid_0's f1-score: 0.807955
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.802969
# [100]	valid_0's f1-score: 0.80167
# Early stopping, best iteration is:
# [16]	valid_0's f1-score: 0.810809
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.746651
# [100]	valid_0's f1-score: 0.753696
# Early stopping, best iteration is:
# [18]	valid_0's f1-score: 0.767822
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.781641
# [100]	valid_0's f1-score: 0.790586
# Early stopping, best iteration is:
# [20]	valid_0's f1-score: 0.845731
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.864918
# [100]	valid_0's f1-score: 0.867577
# Early stopping, best iteration is:
# [32]	valid_0's f1-score: 0.874428
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.776648
# [100]	valid_0's f1-score: 0.775381
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.80685
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.821507
# [100]	valid_0's f1-score: 0.844764
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.879675
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.858826
# [100]	valid_0's f1-score: 0.847204
# Early stopping, best iteration is:
# [6]	valid_0's f1-score: 0.887969
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.860955
# [100]	valid_0's f1-score: 0.856888
# Early stopping, best iteration is:
# [21]	valid_0's f1-score: 0.876959
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.895329
# [100]	valid_0's f1-score: 0.895234
# [150]	valid_0's f1-score: 0.889451
# Early stopping, best iteration is:
# [58]	valid_0's f1-score: 0.907053
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.876056
# [100]	valid_0's f1-score: 0.876056
# Early stopping, best iteration is:
# [20]	valid_0's f1-score: 0.882166
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.828013
# [100]	valid_0's f1-score: 0.815409
# Early stopping, best iteration is:
# [36]	valid_0's f1-score: 0.848175
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.78692
# [100]	valid_0's f1-score: 0.793674
# Early stopping, best iteration is:
# [5]	valid_0's f1-score: 0.834316
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.867036
# [100]	valid_0's f1-score: 0.870418
# [150]	valid_0's f1-score: 0.867483
# Early stopping, best iteration is:
# [55]	valid_0's f1-score: 0.881565
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.916025
# [100]	valid_0's f1-score: 0.921606
# [150]	valid_0's f1-score: 0.918911
# Early stopping, best iteration is:
# [68]	valid_0's f1-score: 0.924489
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.93867
# [100]	valid_0's f1-score: 0.921773
# [150]	valid_0's f1-score: 0.924662
# Early stopping, best iteration is:
# [50]	valid_0's f1-score: 0.93867
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.845661
# [100]	valid_0's f1-score: 0.845322
# Early stopping, best iteration is:
# [24]	valid_0's f1-score: 0.892406
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.742119
# [100]	valid_0's f1-score: 0.729148
# Early stopping, best iteration is:
# [23]	valid_0's f1-score: 0.777986
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.784588
# [100]	valid_0's f1-score: 0.792512
# Early stopping, best iteration is:
# [7]	valid_0's f1-score: 0.821098
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.86923
# [100]	valid_0's f1-score: 0.866589
# Early stopping, best iteration is:
# [27]	valid_0's f1-score: 0.90305
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.905742
# [100]	valid_0's f1-score: 0.905742
# Early stopping, best iteration is:
# [21]	valid_0's f1-score: 0.920598
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.91373
# [100]	valid_0's f1-score: 0.902977
# Early stopping, best iteration is:
# [28]	valid_0's f1-score: 0.925217
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.705633
# [100]	valid_0's f1-score: 0.702505
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 0.717264
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.755148
# [100]	valid_0's f1-score: 0.755497
# Early stopping, best iteration is:
# [13]	valid_0's f1-score: 0.787725
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.752727
# [100]	valid_0's f1-score: 0.742252
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 0.784536
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.760951
# [100]	valid_0's f1-score: 0.760615
# [150]	valid_0's f1-score: 0.758752
# Early stopping, best iteration is:
# [84]	valid_0's f1-score: 0.763191
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.848992
# [100]	valid_0's f1-score: 0.840054
# [150]	valid_0's f1-score: 0.840054
# Early stopping, best iteration is:
# [51]	valid_0's f1-score: 0.852609
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.820495
# [100]	valid_0's f1-score: 0.803042
# Early stopping, best iteration is:
# [44]	valid_0's f1-score: 0.831864
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.739877
# [100]	valid_0's f1-score: 0.735107
# Early stopping, best iteration is:
# [2]	valid_0's f1-score: 0.804321
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.844157
# [100]	valid_0's f1-score: 0.840868
# Early stopping, best iteration is:
# [7]	valid_0's f1-score: 0.873087
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.860325
# [100]	valid_0's f1-score: 0.862574
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.87633
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.871052
# [100]	valid_0's f1-score: 0.863378
# [150]	valid_0's f1-score: 0.869253
# Early stopping, best iteration is:
# [74]	valid_0's f1-score: 0.882615
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.865042
# [100]	valid_0's f1-score: 0.873919
# [150]	valid_0's f1-score: 0.866076
# Early stopping, best iteration is:
# [59]	valid_0's f1-score: 0.880345
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.84348
# [100]	valid_0's f1-score: 0.848173
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.859392
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.725834
# [100]	valid_0's f1-score: 0.732895
# Early stopping, best iteration is:
# [7]	valid_0's f1-score: 0.768282
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.836669
# [100]	valid_0's f1-score: 0.834988
# Early stopping, best iteration is:
# [26]	valid_0's f1-score: 0.866607
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.853189
# [100]	valid_0's f1-score: 0.854319
# Early stopping, best iteration is:
# [28]	valid_0's f1-score: 0.868936
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.750542
# [100]	valid_0's f1-score: 0.752284
# Early stopping, best iteration is:
# [37]	valid_0's f1-score: 0.761496
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.804645
# [100]	valid_0's f1-score: 0.811741
# Early stopping, best iteration is:
# [23]	valid_0's f1-score: 0.815323
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.819175
# [100]	valid_0's f1-score: 0.825315
# Early stopping, best iteration is:
# [33]	valid_0's f1-score: 0.826043
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.933233
# [100]	valid_0's f1-score: 0.933233
# [150]	valid_0's f1-score: 0.927915
# Early stopping, best iteration is:
# [64]	valid_0's f1-score: 0.936147
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.95033
# [100]	valid_0's f1-score: 0.95033
# Early stopping, best iteration is:
# [32]	valid_0's f1-score: 0.953159
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.863253
# [100]	valid_0's f1-score: 0.866759
# Early stopping, best iteration is:
# [33]	valid_0's f1-score: 0.869454
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.918026
# [100]	valid_0's f1-score: 0.921176
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.927416
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.908076
# [100]	valid_0's f1-score: 0.908076
# Early stopping, best iteration is:
# [25]	valid_0's f1-score: 0.919214
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.642235
# [100]	valid_0's f1-score: 0.642235
# Early stopping, best iteration is:
# [2]	valid_0's f1-score: 0.649617
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.643536
# [100]	valid_0's f1-score: 0.643536
# Early stopping, best iteration is:
# [22]	valid_0's f1-score: 0.65235
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.63998
# [100]	valid_0's f1-score: 0.636463
# Early stopping, best iteration is:
# [21]	valid_0's f1-score: 0.656255
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.638022
# [100]	valid_0's f1-score: 0.638022
# Early stopping, best iteration is:
# [12]	valid_0's f1-score: 0.641329
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.684928
# [100]	valid_0's f1-score: 0.68796
# Early stopping, best iteration is:
# [35]	valid_0's f1-score: 0.68796
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.713451
# [100]	valid_0's f1-score: 0.71023
# Early stopping, best iteration is:
# [35]	valid_0's f1-score: 0.716586
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.717538
# [100]	valid_0's f1-score: 0.715279
# Early stopping, best iteration is:
# [14]	valid_0's f1-score: 0.738306
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.834951
# [100]	valid_0's f1-score: 0.838682
# Early stopping, best iteration is:
# [34]	valid_0's f1-score: 0.838682
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.837144
# [100]	valid_0's f1-score: 0.840806
# Early stopping, best iteration is:
# [19]	valid_0's f1-score: 0.851623
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.760553
# [100]	valid_0's f1-score: 0.767022
# [150]	valid_0's f1-score: 0.762493
# Early stopping, best iteration is:
# [86]	valid_0's f1-score: 0.769672
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.776604
# [100]	valid_0's f1-score: 0.776604
# Early stopping, best iteration is:
# [22]	valid_0's f1-score: 0.776604
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.769596
# [100]	valid_0's f1-score: 0.77407
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 0.787449
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.843709
# [100]	valid_0's f1-score: 0.847124
# Early stopping, best iteration is:
# [35]	valid_0's f1-score: 0.850511
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.786983
# [100]	valid_0's f1-score: 0.782666
# Early stopping, best iteration is:
# [32]	valid_0's f1-score: 0.795462
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.858749
# [100]	valid_0's f1-score: 0.858749
# Early stopping, best iteration is:
# [22]	valid_0's f1-score: 0.864134
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.770512
# [100]	valid_0's f1-score: 0.760241
# Early stopping, best iteration is:
# [13]	valid_0's f1-score: 0.775247
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.833291
# [100]	valid_0's f1-score: 0.826507
# Early stopping, best iteration is:
# [28]	valid_0's f1-score: 0.842752
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.823387
# [100]	valid_0's f1-score: 0.819893
# Early stopping, best iteration is:
# [31]	valid_0's f1-score: 0.830821
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.943931
# [100]	valid_0's f1-score: 0.943931
# Early stopping, best iteration is:
# [20]	valid_0's f1-score: 0.95781
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.909844
# [100]	valid_0's f1-score: 0.91521
# Early stopping, best iteration is:
# [30]	valid_0's f1-score: 0.933447
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.832245
# [100]	valid_0's f1-score: 0.82868
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.858074
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.895001
# [100]	valid_0's f1-score: 0.889072
# Early stopping, best iteration is:
# [27]	valid_0's f1-score: 0.913345
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.887735
# [100]	valid_0's f1-score: 0.881627
# Early stopping, best iteration is:
# [21]	valid_0's f1-score: 0.910194
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.648603
# [100]	valid_0's f1-score: 0.65125
# Early stopping, best iteration is:
# [31]	valid_0's f1-score: 0.65125
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.645243
# [100]	valid_0's f1-score: 0.647778
# Early stopping, best iteration is:
# [29]	valid_0's f1-score: 0.653298
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.636212
# [100]	valid_0's f1-score: 0.636212
# Early stopping, best iteration is:
# [31]	valid_0's f1-score: 0.642042
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.64902
# [100]	valid_0's f1-score: 0.6464
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.797912
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.680104
# [100]	valid_0's f1-score: 0.680104
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.850418
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.742342
# [100]	valid_0's f1-score: 0.738879
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.848904
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.698487
# [100]	valid_0's f1-score: 0.695887
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.733262
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.782127
# [100]	valid_0's f1-score: 0.768493
# Early stopping, best iteration is:
# [30]	valid_0's f1-score: 0.796992
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.799858
# [100]	valid_0's f1-score: 0.791716
# Early stopping, best iteration is:
# [25]	valid_0's f1-score: 0.831536
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.734984
# [100]	valid_0's f1-score: 0.733041
# Early stopping, best iteration is:
# [25]	valid_0's f1-score: 0.740569
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.760275
# [100]	valid_0's f1-score: 0.752838
# Early stopping, best iteration is:
# [37]	valid_0's f1-score: 0.767455
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.773838
# [100]	valid_0's f1-score: 0.769464
# Early stopping, best iteration is:
# [28]	valid_0's f1-score: 0.778236
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.840722
# [100]	valid_0's f1-score: 0.840722
# Early stopping, best iteration is:
# [20]	valid_0's f1-score: 0.866894
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.821715
# [100]	valid_0's f1-score: 0.821715
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.832405
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.859002
# [100]	valid_0's f1-score: 0.852326
# Early stopping, best iteration is:
# [20]	valid_0's f1-score: 0.877297
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.637316
# [100]	valid_0's f1-score: 0.641804
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.703168
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.70408
# [100]	valid_0's f1-score: 0.696597
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.778758
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.672272
# [100]	valid_0's f1-score: 0.672272
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.785636
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.906908
# [100]	valid_0's f1-score: 0.897367
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.928843
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.760134
# [100]	valid_0's f1-score: 0.755179
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.80497
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 1
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.643734
# [100]	valid_0's f1-score: 0.643734
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.75242
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.688208
# [100]	valid_0's f1-score: 0.68252
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.837824
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.699301
# [100]	valid_0's f1-score: 0.699301
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.813764
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/bin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
# Early stopping, best iteration is:
# [13]	valid_0's f1-score: 0.784302
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.856533
# [100]	valid_0's f1-score: 0.85963
# Early stopping, best iteration is:
# [37]	valid_0's f1-score: 0.865983
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.964041
# [100]	valid_0's f1-score: 0.96133
# Early stopping, best iteration is:
# [33]	valid_0's f1-score: 0.966761
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.972285
# [100]	valid_0's f1-score: 0.975069
# [150]	valid_0's f1-score: 0.969675
# Early stopping, best iteration is:
# [56]	valid_0's f1-score: 0.977842
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [7]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.787942
# [100]	valid_0's f1-score: 0.791743
# [150]	valid_0's f1-score: 0.799233
# [200]	valid_0's f1-score: 0.79672
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.84788
# [100]	valid_0's f1-score: 0.84788
# [150]	valid_0's f1-score: 0.854508
# [200]	valid_0's f1-score: 0.8603
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.8805
# [100]	valid_0's f1-score: 0.886903
# Early stopping, best iteration is:
# [45]	valid_0's f1-score: 0.889863
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.823552
# [100]	valid_0's f1-score: 0.823552
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.826503
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.816941
# [100]	valid_0's f1-score: 0.819457
# Early stopping, best iteration is:
# [4]	valid_0's f1-score: 0.847377
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.834231
# [100]	valid_0's f1-score: 0.837414
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 0.845423
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.95543
# [100]	valid_0's f1-score: 0.958148
# Early stopping, best iteration is:
# [3]	valid_0's f1-score: 0.969507
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.92011
# [100]	valid_0's f1-score: 0.92011
# Early stopping, best iteration is:
# [1]	valid_0's f1-score: 0.928286
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.950897
# [100]	valid_0's f1-score: 0.956079
# [150]	valid_0's f1-score: 0.956079
# Early stopping, best iteration is:
# [87]	valid_0's f1-score: 0.956079
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.929782
# [100]	valid_0's f1-score: 0.929782
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 0.952368
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.97765
# [100]	valid_0's f1-score: 0.974846
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.983188
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.961633
# [100]	valid_0's f1-score: 0.958758
# Early stopping, best iteration is:
# [12]	valid_0's f1-score: 0.972338
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.660243
# [100]	valid_0's f1-score: 0.658646
# Early stopping, best iteration is:
# [4]	valid_0's f1-score: 0.686884
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.707826
# [100]	valid_0's f1-score: 0.705036
# Early stopping, best iteration is:
# [22]	valid_0's f1-score: 0.714603
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.669982
# [100]	valid_0's f1-score: 0.679995
# Early stopping, best iteration is:
# [25]	valid_0's f1-score: 0.691414
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.721404
# [100]	valid_0's f1-score: 0.724155
# Early stopping, best iteration is:
# [12]	valid_0's f1-score: 0.778529
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.674971
# [100]	valid_0's f1-score: 0.674971
# Early stopping, best iteration is:
# [7]	valid_0's f1-score: 0.715894
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.795106
# [100]	valid_0's f1-score: 0.79831
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.816548
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.902301
# [100]	valid_0's f1-score: 0.893977
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.913755
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.847366
# [100]	valid_0's f1-score: 0.847964
# Early stopping, best iteration is:
# [18]	valid_0's f1-score: 0.86278
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.879869
# [100]	valid_0's f1-score: 0.876828
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.894397
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.816074
# [100]	valid_0's f1-score: 0.803176
# Early stopping, best iteration is:
# [12]	valid_0's f1-score: 0.834333
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.782263
# [100]	valid_0's f1-score: 0.78871
# Early stopping, best iteration is:
# [26]	valid_0's f1-score: 0.814752
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.793757
# [100]	valid_0's f1-score: 0.791056
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.829858
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.873108
# [100]	valid_0's f1-score: 0.878359
# Early stopping, best iteration is:
# [22]	valid_0's f1-score: 0.897295
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.895513
# [100]	valid_0's f1-score: 0.896047
# Early stopping, best iteration is:
# [34]	valid_0's f1-score: 0.907147
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.87638
# [100]	valid_0's f1-score: 0.87638
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.896831
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.895166
# [100]	valid_0's f1-score: 0.892255
# Early stopping, best iteration is:
# [12]	valid_0's f1-score: 0.909692
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.884369
# [100]	valid_0's f1-score: 0.878909
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.896025
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.949765
# [100]	valid_0's f1-score: 0.952502
# Early stopping, best iteration is:
# [47]	valid_0's f1-score: 0.955197
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.826574
# [100]	valid_0's f1-score: 0.829217
# Early stopping, best iteration is:
# [29]	valid_0's f1-score: 0.832754
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.922504
# [100]	valid_0's f1-score: 0.919632
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 0.933874
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.900331
# [100]	valid_0's f1-score: 0.896495
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 0.921967
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.91289
# [100]	valid_0's f1-score: 0.900194
# Early stopping, best iteration is:
# [39]	valid_0's f1-score: 0.925421
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.937709
# [100]	valid_0's f1-score: 0.937709
# Early stopping, best iteration is:
# [40]	valid_0's f1-score: 0.946337
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.785852
# [100]	valid_0's f1-score: 0.788234
# Early stopping, best iteration is:
# [31]	valid_0's f1-score: 0.790931
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.739281
# [100]	valid_0's f1-score: 0.734366
# Early stopping, best iteration is:
# [18]	valid_0's f1-score: 0.747702
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.735114
# [100]	valid_0's f1-score: 0.732867
# Early stopping, best iteration is:
# [19]	valid_0's f1-score: 0.753891
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.832438
# [100]	valid_0's f1-score: 0.835144
# Early stopping, best iteration is:
# [38]	valid_0's f1-score: 0.842393
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.949207
# [100]	valid_0's f1-score: 0.946508
# Early stopping, best iteration is:
# [7]	valid_0's f1-score: 0.957992
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.934411
# [100]	valid_0's f1-score: 0.940321
# Early stopping, best iteration is:
# [31]	valid_0's f1-score: 0.946156
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.852486
# [100]	valid_0's f1-score: 0.842377
# Early stopping, best iteration is:
# [33]	valid_0's f1-score: 0.855256
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.857546
# [100]	valid_0's f1-score: 0.854512
# Early stopping, best iteration is:
# [32]	valid_0's f1-score: 0.865296
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.934938
# [100]	valid_0's f1-score: 0.940376
# [150]	valid_0's f1-score: 0.940376
# Early stopping, best iteration is:
# [97]	valid_0's f1-score: 0.940376
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.921574
# [100]	valid_0's f1-score: 0.924501
# Early stopping, best iteration is:
# [16]	valid_0's f1-score: 0.930117
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.907434
# [100]	valid_0's f1-score: 0.90178
# Early stopping, best iteration is:
# [38]	valid_0's f1-score: 0.910948
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.86272
# [100]	valid_0's f1-score: 0.867217
# Early stopping, best iteration is:
# [18]	valid_0's f1-score: 0.882616
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.868543
# [100]	valid_0's f1-score: 0.867874
# Early stopping, best iteration is:
# [11]	valid_0's f1-score: 0.883014
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [8]	valid_0's f1-score: 1
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.943604
# [100]	valid_0's f1-score: 0.940688
# Early stopping, best iteration is:
# [12]	valid_0's f1-score: 0.960891
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.908375
# [100]	valid_0's f1-score: 0.893924
# Early stopping, best iteration is:
# [38]	valid_0's f1-score: 0.911211
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.928006
# [100]	valid_0's f1-score: 0.92257
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.928117
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.912374
# [100]	valid_0's f1-score: 0.906705
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 0.914959
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.953442
# [100]	valid_0's f1-score: 0.950693
# Early stopping, best iteration is:
# [44]	valid_0's f1-score: 0.953442
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.905444
# [100]	valid_0's f1-score: 0.900098
# Early stopping, best iteration is:
# [30]	valid_0's f1-score: 0.90868
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.939567
# [100]	valid_0's f1-score: 0.942262
# Early stopping, best iteration is:
# [30]	valid_0's f1-score: 0.942484
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.936938
# [100]	valid_0's f1-score: 0.930845
# Early stopping, best iteration is:
# [20]	valid_0's f1-score: 0.939958
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.954857
# [100]	valid_0's f1-score: 0.949018
# Early stopping, best iteration is:
# [30]	valid_0's f1-score: 0.960636
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.944776
# [100]	valid_0's f1-score: 0.942047
# Early stopping, best iteration is:
# [41]	valid_0's f1-score: 0.947514
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.794002
# [100]	valid_0's f1-score: 0.794002
# Early stopping, best iteration is:
# [26]	valid_0's f1-score: 0.804419
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.803724
# [100]	valid_0's f1-score: 0.793224
# Early stopping, best iteration is:
# [41]	valid_0's f1-score: 0.80618
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.759994
# [100]	valid_0's f1-score: 0.764192
# Early stopping, best iteration is:
# [5]	valid_0's f1-score: 0.768683
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.702136
# [100]	valid_0's f1-score: 0.697666
# [150]	valid_0's f1-score: 0.708822
# [200]	valid_0's f1-score: 0.704448
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.868991
# [100]	valid_0's f1-score: 0.876297
# [150]	valid_0's f1-score: 0.876297
# Early stopping, best iteration is:
# [55]	valid_0's f1-score: 0.876297
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.905643
# [100]	valid_0's f1-score: 0.900364
# [150]	valid_0's f1-score: 0.900364
# Early stopping, best iteration is:
# [60]	valid_0's f1-score: 0.906757
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.828874
# [100]	valid_0's f1-score: 0.829945
# Early stopping, best iteration is:
# [34]	valid_0's f1-score: 0.836077
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.854789
# [100]	valid_0's f1-score: 0.845883
# Early stopping, best iteration is:
# [6]	valid_0's f1-score: 0.87742
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.91132
# [100]	valid_0's f1-score: 0.916838
# Early stopping, best iteration is:
# [27]	valid_0's f1-score: 0.924724
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.939355
# [100]	valid_0's f1-score: 0.942035
# Early stopping, best iteration is:
# [24]	valid_0's f1-score: 0.947515
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.909491
# [100]	valid_0's f1-score: 0.906611
# Early stopping, best iteration is:
# [6]	valid_0's f1-score: 0.932972
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.883828
# [100]	valid_0's f1-score: 0.878292
# Early stopping, best iteration is:
# [22]	valid_0's f1-score: 0.902466
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.900743
# [100]	valid_0's f1-score: 0.892532
# Early stopping, best iteration is:
# [34]	valid_0's f1-score: 0.904228
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 0.930249
# [100]	valid_0's f1-score: 0.933001
# Early stopping, best iteration is:
# [10]	valid_0's f1-score: 0.938922
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's f1-score: 1
# [100]	valid_0's f1-score: 1
# Early stopping, best iteration is:
# [9]	valid_0's f1-score: 1

# %%
result_df.to_csv('CSV/song1_result-nn.csv', index=False)
