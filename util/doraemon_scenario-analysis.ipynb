# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
result_df = pd.read_csv('CSV/song1_result-sc-yy.csv')
result_df
# Out:
#     test_who  test_porder  test_score  f1_score
# 0          1            1      243400    0.9280
# 1          1            2      223010    0.9471
# 2          1            3      181870    0.9332
# 3          2            1      210550    0.9723
# 4          2            2      251930    0.8826
# 5          2            3      223700    0.9411
# 6          3            1      110320    0.9614
# 7          3            2      122580    0.9668
# 8          3            3      112370    0.9695
# 9          4            1      222600    0.8863
# 10         4            2      267800    0.8860
# 11         4            3      271990    0.8792
# 12         5            1      131210    0.8579
# 13         5            2      188720    0.9481
# 14         5            3      185380    0.9372
# 15         6            1      241880    0.9323
# 16         6            2      164810    0.9319
# 17         6            3      266820    0.9586
# 18         7            1      269500    0.9805
# 19         7            2      278840    0.9750
# 20         7            3      274760    0.9582
# 21         8            1      170430    0.9456
# 22         8            2       89370    0.9343
# 23         8            3      142120    0.9483

# %%
sns.catplot(x="test_who", y="f1_score",
            capsize=.2, palette="YlGnBu_d", aspect=2,
            kind="point", data=result_df, vmax=1)
plt.show()

# %%
f, axes = plt.subplots(2, 2, sharex='all', sharey='all', figsize=(15, 10))
for song in range(4):
    df = pd.read_csv('CSV/song' + str(song + 1) + '_result-sc-yy.csv')
    sns.catplot(x='test_who', y='f1_score', data=df, ax=axes[song // 2, song % 2],
                kind="point")
    axes[song // 2, song % 2].set_title('song %d' % (song + 1))
plt.show()
