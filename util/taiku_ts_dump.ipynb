# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys

from datetime import datetime, timedelta
from tqdm import tqdm

LEFT_PATH = '../data/bb_left_forearm_csv/'
RIGHT_PATH = '../data/bb_right_forearm_csv/'
TABLE_PATH = '../data/taiku_tables/'
PATH = '../data/bb_capture/'
OUTPUT_PATH = '../output/'
PROCESSED_PATH = '../data/'

# %%
df = pd.read_csv(TABLE_PATH + 'taiko_play.csv')
tmp_df = pd.read_csv(TABLE_PATH + 'taiko_song.csv', dtype={
    'song_length': np.int16
})
df = df.merge(tmp_df, how='left', left_on='song_id', right_on='song_id')
tmp_df = pd.read_csv(TABLE_PATH + 'taiko_drumer.csv')
df = df.merge(tmp_df, how='left', left_on='drumer_id', right_on='id')
local_time = df['start_time'][0]
df.head(68)
# Out:
#     pid  drumer_id  song_id  performance_order          start_time  \
# 0     1          1        1                  1  3/27/2018 11:53:08
# 1     2          1        1                  2  3/27/2018 11:55:29
# 2     3          1        1                  3  3/27/2018 11:57:53
# 3     4          1        2                  1  3/27/2018 12:27:53
# 4     5          1        2                  2  3/27/2018 12:30:18
# 5     6          1        2                  3  3/27/2018 12:32:45
# 6     7          1        3                  1  3/27/2018 12:35:45
# 7     8          1        3                  2  3/27/2018 12:38:33
# 8     9          1        3                  3  3/27/2018 12:41:25
# 9    10          1        4                  1  3/27/2018 12:44:52
# 10   11          1        4                  2  3/27/2018 12:46:54
# 11   12          1        4                  3  3/27/2018 12:49:02
# 12   13          1        4                  4  3/27/2018 12:51:07
# 13   14          2        1                  1  3/27/2018 13:28:02
# 14   15          2        1                  2  3/27/2018 13:30:23
# 15   16          2        1                  3  3/27/2018 13:32:32
# 16   17          2        2                  1  3/27/2018 13:34:43
# 17   18          2        2                  2  3/27/2018 13:37:06
# 18   19          2        2                  3  3/27/2018 13:39:31
# 19   20          2        3                  1  3/27/2018 13:43:06
# 20   21          2        3                  2  3/27/2018 13:46:01
# 21   22          2        3                  3  3/27/2018 13:48:54
# 22   23          2        4                  1  3/27/2018 13:52:15
# 23   24          2        4                  2  3/27/2018 13:54:19
# 24   25          2        4                  3  3/27/2018 13:56:20
# 25   26          2        4                  4  3/27/2018 13:58:17
# 26   27          3        1                  1  3/27/2018 15:01:10
# 27   28          3        1                  2  3/27/2018 15:03:21
# 28   29          3        1                  3  3/27/2018 15:05:37
# 29   30          3        2                  1  3/27/2018 15:07:51
# ..  ...        ...      ...                ...                 ...
# 38   39          3        4                  4  3/27/2018 15:30:59
# 39   40          4        1                  1  3/27/2018 15:37:57
# 40   41          4        1                  2  3/27/2018 15:39:57
# 41   42          4        1                  3  3/27/2018 15:41:56
# 42   43          4        2                  1  3/27/2018 15:44:09
# 43   44          4        2                  2  3/27/2018 15:46:30
# 44   45          4        2                  3  3/27/2018 15:48:52
# 45   46          4        3                  1  3/27/2018 15:52:26
# 46   47          4        3                  2  3/27/2018 15:55:21
# 47   48          4        3                  3  3/27/2018 15:58:17
# 48   49          4        4                  1  3/27/2018 16:01:20
# 49   50          4        4                  2  3/27/2018 16:03:21
# 50   51          4        4                  3  3/27/2018 16:05:24
# 51   52          4        4                  4  3/27/2018 16:07:26
# 52   53          5        1                  1  3/27/2018 16:18:30
# 53   54          5        1                  2  3/27/2018 16:20:44
# 54   55          5        1                  3  3/27/2018 16:22:47
# 55   56          5        2                  1  3/27/2018 16:25:10
# 56   57          5        2                  2  3/27/2018 16:27:53
# 57   58          5        2                  3  3/27/2018 16:30:11
# 58   59          5        3                  1  3/27/2018 16:33:25
# 59   60          5        3                  2  3/27/2018 16:36:14
# 60   61          5        3                  3  3/27/2018 16:39:15
# 61   62          5        4                  1  3/27/2018 16:42:20
# 62   63          5        4                  2  3/27/2018 16:44:22
# 63   64          5        4                  3  3/27/2018 16:47:05
# 64   65          5        4                  4  3/27/2018 16:49:41
# 65   66          7        1                  1  3/28/2018 14:59:10
# 66   67          7        1                  2  3/28/2018 15:01:26
# 67   68          7        1                  3  3/28/2018 15:03:47
#
#       song_name  song_length  id name  handedness gender  armlength
# 0   夢をかなえてドラえもん           90   1  陳啟元           0      M       26.0
# 1   夢をかなえてドラえもん           90   1  陳啟元           0      M       26.0
# 2   夢をかなえてドラえもん           90   1  陳啟元           0      M       26.0
# 3       ウィーアー！           120   1  陳啟元           0      M       26.0
# 4       ウィーアー！           120   1  陳啟元           0      M       26.0
# 5       ウィーアー！           120   1  陳啟元           0      M       26.0
# 6    六兆年と一夜物語\n          150   1  陳啟元           0      M       26.0
# 7    六兆年と一夜物語\n          150   1  陳啟元           0      M       26.0
# 8    六兆年と一夜物語\n          150   1  陳啟元           0      M       26.0
# 9    残酷な天使のテーゼ            90   1  陳啟元           0      M       26.0
# 10   残酷な天使のテーゼ            90   1  陳啟元           0      M       26.0
# 11   残酷な天使のテーゼ            90   1  陳啟元           0      M       26.0
# 12   残酷な天使のテーゼ            90   1  陳啟元           0      M       26.0
# 13  夢をかなえてドラえもん           90   2  江彥勳           0      M       30.0
# 14  夢をかなえてドラえもん           90   2  江彥勳           0      M       30.0
# 15  夢をかなえてドラえもん           90   2  江彥勳           0      M       30.0
# 16      ウィーアー！           120   2  江彥勳           0      M       30.0
# 17      ウィーアー！           120   2  江彥勳           0      M       30.0
# 18      ウィーアー！           120   2  江彥勳           0      M       30.0
# 19   六兆年と一夜物語\n          150   2  江彥勳           0      M       30.0
# 20   六兆年と一夜物語\n          150   2  江彥勳           0      M       30.0
# 21   六兆年と一夜物語\n          150   2  江彥勳           0      M       30.0
# 22   残酷な天使のテーゼ            90   2  江彥勳           0      M       30.0
# 23   残酷な天使のテーゼ            90   2  江彥勳           0      M       30.0
# 24   残酷な天使のテーゼ            90   2  江彥勳           0      M       30.0
# 25   残酷な天使のテーゼ            90   2  江彥勳           0      M       30.0
# 26  夢をかなえてドラえもん           90   3  葉庭恩           0      F       26.0
# 27  夢をかなえてドラえもん           90   3  葉庭恩           0      F       26.0
# 28  夢をかなえてドラえもん           90   3  葉庭恩           0      F       26.0
# 29      ウィーアー！           120   3  葉庭恩           0      F       26.0
# ..          ...          ...  ..  ...         ...    ...        ...
# 38   残酷な天使のテーゼ            90   3  葉庭恩           0      F       26.0
# 39  夢をかなえてドラえもん           90   4  傅枝燁           0      F       25.5
# 40  夢をかなえてドラえもん           90   4  傅枝燁           0      F       25.5
# 41  夢をかなえてドラえもん           90   4  傅枝燁           0      F       25.5
# 42      ウィーアー！           120   4  傅枝燁           0      F       25.5
# 43      ウィーアー！           120   4  傅枝燁           0      F       25.5
# 44      ウィーアー！           120   4  傅枝燁           0      F       25.5
# 45   六兆年と一夜物語\n          150   4  傅枝燁           0      F       25.5
# 46   六兆年と一夜物語\n          150   4  傅枝燁           0      F       25.5
# 47   六兆年と一夜物語\n          150   4  傅枝燁           0      F       25.5
# 48   残酷な天使のテーゼ            90   4  傅枝燁           0      F       25.5
# 49   残酷な天使のテーゼ            90   4  傅枝燁           0      F       25.5
# 50   残酷な天使のテーゼ            90   4  傅枝燁           0      F       25.5
# 51   残酷な天使のテーゼ            90   4  傅枝燁           0      F       25.5
# 52  夢をかなえてドラえもん           90   5  塗沛宬           0      M       30.0
# 53  夢をかなえてドラえもん           90   5  塗沛宬           0      M       30.0
# 54  夢をかなえてドラえもん           90   5  塗沛宬           0      M       30.0
# 55      ウィーアー！           120   5  塗沛宬           0      M       30.0
# 56      ウィーアー！           120   5  塗沛宬           0      M       30.0
# 57      ウィーアー！           120   5  塗沛宬           0      M       30.0
# 58   六兆年と一夜物語\n          150   5  塗沛宬           0      M       30.0
# 59   六兆年と一夜物語\n          150   5  塗沛宬           0      M       30.0
# 60   六兆年と一夜物語\n          150   5  塗沛宬           0      M       30.0
# 61   残酷な天使のテーゼ            90   5  塗沛宬           0      M       30.0
# 62   残酷な天使のテーゼ            90   5  塗沛宬           0      M       30.0
# 63   残酷な天使のテーゼ            90   5  塗沛宬           0      M       30.0
# 64   残酷な天使のテーゼ            90   5  塗沛宬           0      M       30.0
# 65  夢をかなえてドラえもん           90   7  王名宸           1      M       26.5
# 66  夢をかなえてドラえもん           90   7  王名宸           1      M       26.5
# 67  夢をかなえてドラえもん           90   7  王名宸           1      M       26.5
#
# [68 rows x 12 columns]

# %%
def get_hwclock_time(local_time, delta=0):
    d = datetime.strptime(local_time, "%m/%d/%Y %H:%M:%S")
    d = d + timedelta(seconds=int(delta))
    return time.mktime(d.timetuple())

# %%
files = next(os.walk(LEFT_PATH))[2]
left_df = [
    pd.read_csv(LEFT_PATH + filename, dtype={
        'timestamp': np.float64
    }) for filename in files
]
left_df = pd.concat(left_df, ignore_index=True)
left_df.drop('key', axis=1, inplace=True)
files
# Out:
# ['data_2018_03_27_13_25_43.csv',
#  'data_2018_03_28_15_52_48.csv',
#  'data_2018_03_27_14_48_28.csv',
#  'data_2018_03_28_16_59_47.csv',
#  'data_2018_03_27_11_37_57.csv',
#  'data_2018_03_28_14_52_45.csv',
#  'data_2018_03_27_16_12_02.csv',
#  'data_2018_03_31_15_29_36.csv']

# %%
files = next(os.walk(RIGHT_PATH))[2]
right_df = [
    pd.read_csv(RIGHT_PATH + filename, dtype={
        'timestamp': np.float64
    }) for filename in files
]
right_df = pd.concat(right_df, ignore_index=True)
right_df.drop('key', axis=1, inplace=True)
files
# Out:
# ['data_2018_03_27_11_40_03.csv',
#  'data_2018_03_28_16_59_37.csv',
#  'data_2018_03_27_14_50_24.csv',
#  'data_2018_03_28_14_52_43.csv',
#  'data_2018_03_31_15_29_27.csv',
#  'data_2018_03_27_16_14_52.csv',
#  'data_2018_03_28_15_52_55.csv',
#  'data_2018_03_27_13_20_28.csv']

# %%
for col in left_df:
    if col != 'timestamp' and col != 'wall_time':
        print('retrieving column %s ...' % (str(col)))
        sys.stdout.flush()
        
        # access particular folder, if doesn't exist, create it
        directory = OUTPUT_PATH + str(col)   
        if not os.path.exists(directory):
            os.makedirs(directory)
            
        for i in tqdm(range(len(df))):
            plt.figure(figsize=(15, 8))
            row = df.iloc[i]
            start_time = get_hwclock_time(row['start_time'])
            end_time = get_hwclock_time(row['start_time'], row['song_length'])
            play_df = left_df[(left_df['timestamp'] >= start_time) & (left_df['timestamp'] <= end_time)]
            plt.plot(play_df['timestamp'], play_df[col], label='left')
            
            play_df = right_df[(right_df['timestamp'] >= start_time) & (right_df['timestamp'] <= end_time)]
            plt.plot(play_df['timestamp'], play_df[col], label='right')
            
            plt.legend()
            save_name = '%s who_id:%d song_id:%d order:%d' % (col, row['id'], row['song_id'], row['performance_order'])
            plt.title(save_name)
            plt.savefig(directory + '/' + save_name + '.png')
            plt.close()
# Out:
# retrieving column imu_temp ...
# 100%|██████████| 104/104 [00:12<00:00,  8.46it/s]
# retrieving column imu_ax ...
# 100%|██████████| 104/104 [00:13<00:00,  7.79it/s]
# retrieving column imu_ay ...
# 100%|██████████| 104/104 [00:13<00:00,  7.74it/s]
# retrieving column imu_az ...
# 100%|██████████| 104/104 [00:13<00:00,  7.68it/s]
# retrieving column imu_gx ...
# 100%|██████████| 104/104 [00:14<00:00,  7.30it/s]
# retrieving column imu_gy ...
# 100%|██████████| 104/104 [00:13<00:00,  7.49it/s]
# retrieving column imu_gz ...
# 100%|██████████| 104/104 [00:14<00:00,  7.20it/s]
# retrieving column msu_ax ...
# 100%|██████████| 104/104 [00:12<00:00,  8.47it/s]
# retrieving column msu_ay ...
# 100%|██████████| 104/104 [00:12<00:00,  8.25it/s]
# retrieving column msu_az ...
# 100%|██████████| 104/104 [00:12<00:00,  8.40it/s]
# retrieving column baro_temp ...
# 100%|██████████| 104/104 [00:10<00:00,  9.46it/s]
# retrieving column baro ...
# 100%|██████████| 104/104 [00:13<00:00,  7.96it/s]
